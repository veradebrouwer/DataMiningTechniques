# %% [markdown]
# # Importing

# %%
import pandas as pd

# %%
trainingSet = pd.read_csv("data/training_set_VU_DM.csv")

# %%
trainingSet
# Out:
#          srch_id            date_time  site_id  visitor_location_country_id  \
# 0              1  2013-04-04 08:32:15       12                          187
# 1              1  2013-04-04 08:32:15       12                          187
# 2              1  2013-04-04 08:32:15       12                          187
# 3              1  2013-04-04 08:32:15       12                          187
# 4              1  2013-04-04 08:32:15       12                          187
# ...          ...                  ...      ...                          ...
# 4958342   332785  2013-06-30 19:55:18        5                          219
# 4958343   332785  2013-06-30 19:55:18        5                          219
# 4958344   332785  2013-06-30 19:55:18        5                          219
# 4958345   332785  2013-06-30 19:55:18        5                          219
# 4958346   332785  2013-06-30 19:55:18        5                          219
#
# ...

# %% [markdown]
# # Some EDA

# %%
trainingSet['visitor_location_country_id'].value_counts().nlargest(n=10).plot(kind='bar', legend=None, title="Distribution of visitor countries")

# %%
trainingSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4958347 entries, 0 to 4958346
# Data columns (total 54 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   srch_id                      int64
#  1   date_time                    object
#  2   site_id                      int64
#  3   visitor_location_country_id  int64
#  4   visitor_hist_starrating      float64
#  5   visitor_hist_adr_usd         float64
#  6   prop_country_id              int64
#  7   prop_id                      int64
#  8   prop_starrating              int64
#  9   prop_review_score            float64
#  10  prop_brand_bool              int64
#  11  prop_location_score1         float64
#  12  prop_location_score2         float64
#  13  prop_log_historical_price    float64
#  14  position                     int64
#  15  price_usd                    float64
#  16  promotion_flag               int64
#  17  srch_destination_id          int64
# ...

# %%
trainingSet['visitor_hist_starrating'].mean()
# Out:
# 3.374334050646105

# %%
trainingSet['prop_brand_bool'].value_counts().plot(kind='bar')

# %%
trainingSet['srch_saturday_night_bool'].value_counts().plot(kind='pie')

# %% [markdown]
# # Correlation Matrix

# %%
trainingSet.corr()
